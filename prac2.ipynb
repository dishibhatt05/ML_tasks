# %% [markdown]
# <a href="https://colab.research.google.com/github/dishibhatt05/ML_tasks/blob/data_processing/prac2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
x=[4,7,8,9,11,5]
y=[13,23,5,7,9,3]
player=["virat","dhoni","vijay","dhawan"]
runs=[120,44,77,33]
exp=[0.1,0,0,0]

# %%
plt.xlabel("x-axis")
plt.ylabel("y-axis")
#plt.plot(x,y)
#plt.bar(x,y)
#plt.bar(player,runs)
plt.scatter(x,y)
plt.grid(color="green")
plt.show()

# %%
#plt.xlabel("x-axis")
#plt.ylabel("y-axis")
plt.pie(runs,labels=player,explode=exp,shadow="true",autopct="%1.1f%%")
plt.grid(color="green")
plt.show()
